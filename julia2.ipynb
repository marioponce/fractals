# %%
from julia import Julia

# %%
pars ={
    "C" : [-1, -0.004],
    "tol" : 6,
    "res" : [1000, 1000],
    "r_lim" : [-2.5, 2.5],
    "j_lim" : [-2.5, 2.5],
    "col" : "jet",
    "max_iter": 50,
    }

js = Julia(pars)
js.do_iter()
js.do_plot()

# %%
# js.do_ani()

# %%
# pars ={
#     "C" : [-1, -0.0],
#     "tol" : 6,
#     "res" : [1000, 1000],
#     "r_lim" : [-2.5, 2.5],
#     "j_lim" : [-2.5, 2.5],
#     "col" : "jet",
#     "max_iter": 30,
#     "func"  :"pow2"
#     }
# ms = Mandelbrot(pars)

# %%
# ms.do_iter()
# ms.do_plot()

# %%
# ms.do_ani()
